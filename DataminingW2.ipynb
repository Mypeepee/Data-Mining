# %% [markdown]
# ## Week 2
#
# Please print your name and your NIM.

# %%
# here
print("Jason Christopher Liendo - 0706022210018")
# Out:
# Jason Christopher Liendo - 0706022210018

# %% [markdown]
# ## Pandas

# %% [markdown]
# Please import the necessary library here.

# %%
# Import Library
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h1> Import Data

# %% [markdown]
# Please download the data from zip Elearn. <br>
# then put it on your own github account:
# 1. CSV File (Ice Cream)
# 2. Excel File (Maven Business School)
# 3. JSON File (Drake)
# 4. Text File, add header 'English' and 'France' (eng-fra)
# 5. Web Dataset - https://raw.githubusercontent.com/michellechandraa/TutorDataMining/refs/heads/main/menu.csv
#
# convert the datasets into dataframe using github url.

# %%
# 1
url = "https://raw.githubusercontent.com/Mypeepee/Dataset---Datamining/refs/heads/main/menu.csv"
dfmenu = pd.read_csv(url)
dfmenu.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
# 2
import urllib.request
import pandas as pd

# URL to the Excel file
url = "https://github.com/Mypeepee/Dataset---Datamining/raw/main/Maven%20Business%20School.xlsx"

# Download the file from the URL
excel_file = 'Maven_Business_School.xlsx'
urllib.request.urlretrieve(url, excel_file)

# Load the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Show the first few rows of the DataFrame
df.head()
# Out:
#    Student ID  Undergrad Degree  Undergrad Grade  MBA Grade Work Experience  \
# 0           1          Business             68.4       90.2              No
# 1           2          Business             62.1       92.8              No
# 2           3  Computer Science             70.2       68.7             Yes
# 3           4       Engineering             75.1       80.7              No
# 4           5           Finance             60.9       74.9              No
#
#    Employability (Before)  Employability (After)      Status  Annual Salary
# 0                   252.0                  276.0      Placed       111000.0
# 1                   423.0                  410.0  Not Placed            NaN
# 2                   101.0                  119.0      Placed       107000.0
# 3                   288.0                  334.0  Not Placed            NaN
# 4                   248.0                  252.0  Not Placed            NaN

# %%
# 3
import json
import urllib.request
import pandas as pd

# URL to the JSON file
url = "https://raw.githubusercontent.com/Mypeepee/Dataset---Datamining/refs/heads/main/drake_data.json"

# Fetch and load the JSON data from the URL
with urllib.request.urlopen(url) as response:
    data = json.loads(response.read().decode())

# Convert the JSON data into a pandas DataFrame
df = pd.DataFrame(data)

# Show the first few rows of the DataFrame
df.head()
# Out:
#                  album                           lyrics_title  \
# 0  Certified Lover Boy            Certified Lover Boy* Lyrics
# 1  Certified Lover Boy  Like I’m Supposed To/Do Things Lyrics
# 2  Certified Lover Boy                      Not Around Lyrics
# 3  Certified Lover Boy    In the Cut (Ft. Roddy Ricch) Lyrics
# 4  Certified Lover Boy  Zodiac Sign (Ft. Jessie Reyez) Lyrics
#
#                                           lyrics_url  \
# 0  https://genius.com/Drake-certified-lover-boy-l...
# 1  https://genius.com/Drake-like-im-supposed-to-d...
# 2         https://genius.com/Drake-not-around-lyrics
# 3         https://genius.com/Drake-in-the-cut-lyrics
# 4        https://genius.com/Drake-zodiac-sign-lyrics
#
#                                               lyrics track_views
# 0  Lyrics from CLB Merch\n\n[Verse]\nPut my feeli...        8.7K
# 1  [Verse]\nHands are tied\nSomeone's in my ear f...       38.8K
# 2  [Intro]\nYeah, we back\nWassup ladies?\nSwisha...      129.8K
# ...

# %%
# 4
url = "https://raw.githubusercontent.com/Mypeepee/Dataset---Datamining/refs/heads/main/eng-fra.txt"

# Fetch and read the content of the .txt file
with urllib.request.urlopen(url) as response:
    data = response.read().decode()

# Print the first 10 lines to inspect the content
lines = data.split('\n')  # Split the content by lines
for line in lines[:10]:  # Show the first 10 lines
    print(line)
# Out:
# Go.	Va !
# Run!	Cours !
# Run!	Courez !
# Wow!	Ça alors !
# Fire!	Au feu !
# Help!	À l'aide !
# Jump.	Saute.
# Stop!	Ça suffit !
# Stop!	Stop !
# Stop!	Arrête-toi !

# %%
# 5
url = "https://raw.githubusercontent.com/Mypeepee/Dataset---Datamining/refs/heads/main/menu.csv"
dfmenu = pd.read_csv(url)
dfmenu.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# <h1> Try Yourself

# %% [markdown]
# a. Import MLBB HERO DATASET into dataframe <br>
# b. show 10 random data from dataset <br>
# c. Find out if there are any missing values in each column <br>
# d. drop the unnecessary column <br>
# e. show the roles of the hero in that dataset <br>
# f. show the most difficult hero to use<br>
# g. find out which ones has the average higher physical_atk between Fighters and Tank<br>
# output example: <br>
# "Fighters have higher average physical attack than Tanks." <br>
# "Tanks have higher average physical attack than Fighters." <br>
# "Fighters and Tanks have the same average physical attack." <br>
# h. Make a visualization showing percentages of heroes based on their role

# %%
# URL to the CSV file
url = "https://raw.githubusercontent.com/Mypeepee/Dataset---Datamining/refs/heads/main/mlbb_hero.csv"
data = pd.read_csv(url, delimiter=';')  # Specify the delimiter

# Step 3: Display the data with proper formatting
data.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# ...

# %%
# b
random_data = data.sample(10)
random_data.head(10)
# Out:
#     hero_name      role  defense_overall  offense_overall  \
# 11      Kimmy  marksman              5.0              7.0
# 1      Martis   fighter              6.0              8.0
# 78       Ling  assassin              5.0              8.0
# 73     Harley      mage              4.0              6.0
# 51     Eudora      mage              4.0              5.0
# 25      Clint  marksman              4.0              8.0
# 64       Chou   fighter              7.0              8.0
# 41      Hilda   fighter              8.0              6.0
# 49    Rafaela   support              5.0              4.0
# 99  Benedetta  assassin              5.0              6.0
#
#     skill_effect_overall  difficulty_overall  movement_spd  magic_defense  \
# 11                   8.0                 7.0           245             10
# 1                    5.0                 5.0           260             10
# 78                   6.0                 8.0           260             10
# ...

# %%
# c
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# hero_name                 0
# role                      0
# defense_overall           0
# offense_overall           0
# skill_effect_overall      0
# difficulty_overall        0
# movement_spd              0
# magic_defense             0
# mana                      0
# hp_regen                  0
# physical_atk              0
# physical_defense          0
# hp                        0
# attack_speed              0
# mana_regen                0
# win_rate                  0
# pick_rate                 0
# ban_rate                  0
# release_year              0
# Unnamed: 19             103
# dtype: int64

# %%
# d
data_cleaned = data.drop(columns=['Unnamed: 19'], errors='ignore')
data_cleaned.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# ...

# %%
# e
unique_roles = data_cleaned['role'].unique()
print(unique_roles)
# Out:
# ['fighter' 'tank' 'support' 'marksman' 'mage' 'assassin']

# %%
# f
most_difficult_hero = data_cleaned.loc[data_cleaned['difficulty_overall'].idxmax()]
print(f"The most difficult hero to use is {most_difficult_hero['hero_name']}.")
# Out:
# The most difficult hero to use is Fanny.

# %%
# g
average_physical_atk_fighters = data_cleaned[data_cleaned['role'] == 'Fighter']['physical_atk'].mean()
average_physical_atk_tanks = data_cleaned[data_cleaned['role'] == 'Tank']['physical_atk'].mean()

if average_physical_atk_fighters > average_physical_atk_tanks:
    result = "Fighters have higher average physical attack than Tanks."
elif average_physical_atk_fighters < average_physical_atk_tanks:
    result = "Tanks have higher average physical attack than Fighters."
else:
    result = "Fighters and Tanks have the same average physical attack."

print(result)
# Out:
# Fighters and Tanks have the same average physical attack.

# %%
# h
role_counts = data_cleaned['role'].value_counts()
role_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, title='Percentage of Heroes by Role', figsize=(8, 8))
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# 7. I have a character with this specification:
# defense_overall 6.0<br>
# offense_overall 7.0<br>
# skill_effect_overall 4.0<br>
# difficulty_overall 3.0<br>
# movement_spd 250<br>
# magic_defense 9<br>
# mana 380<br>
# hp_regen 37<br>
# physical_atk 119<br>
# physical_defense 24<br>
# hp 2689<br>
# attack_speed 0.75<br>
# mana_regen 16.0<br>
#
# Please predict its role using DecisionTree classification algorithm <br>

# %%
# 7

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

df=pd.DataFrame(df)

# Encode the 'role' column
label_encoder = LabelEncoder()
df['role'] = label_encoder.fit_transform(df['role'])

# Separate features and target variable
X = df.drop(columns=['hero_name', 'role', 'ban_rate', 'pick_rate', 'release_year', 'win_rate'])
y = df['role']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# Create a Decision Tree Classifier
classifier = DecisionTreeClassifier(random_state=10)

# Train the model
classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Character specifications to predict the role
new_character = pd.DataFrame({
    "defense_overall": [6.0],
    "offense_overall": [7.0],
    "skill_effect_overall": [4.0],
    "difficulty_overall": [3.0],
    "movement_spd": [250],
    "magic_defense": [9],
    "mana": [380],
    "hp_regen": [37],
    "physical_atk": [119],
    "physical_defense": [24],
    "hp": [2689],
    "attack_speed": [0.75],
    "mana_regen": [16.0]
})

# Predict the role for the given character
predicted_role = classifier.predict(new_character)

# Decode the predicted role back to original labels
predicted_role_label = label_encoder.inverse_transform(predicted_role)

# Print the predicted role
print("Predicted role for the character:", predicted_role_label[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'role'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# 8. Why is CSV one of the most commonly used file formats in the field of data science? <br>

# %%
# 8
CSV, which stands for Comma-Separated Values, is a very popular file format used in data science for several simple reasons:

Easy to Read: CSV files are plain text files, which means they are just simple text. You can open them in any text editor (like Notepad) and see the data clearly, with each piece of information separated by commas.

Simple Format: In a CSV file, data is organized in rows and columns, just like a table. Each row represents a different item (like a person or a product), and each column represents a specific attribute (like name, age, or price). This makes it really easy to understand and work with.

Widely Supported: Almost all data programs, including spreadsheets like Microsoft Excel and data analysis tools like Python and R, can read and write CSV files. This means you can easily share your data with others or use it in different programs without worrying about compatibility.

Lightweight: CSV files are usually smaller in size compared to other file formats like Excel. This makes them faster to load and easier to share, especially when dealing with large datasets.

Flexibility: You can store all kinds of data in a CSV file—numbers, text, dates, and more. This flexibility allows it to be used in many different areas, not just data science.

So, because CSV files are easy to read, simple to use, widely supported, lightweight, and flexible, they are one of the most commonly used file formats in data science!

Source = ChatGPT
prompt = Why is CSV one of the most commonly used file formats in the field of data science?
please answer this like im on junior school
